# %% [markdown]
# ## Подключение библиотек
#
# - pandas — используется для загрузки и обработки табличных данных.
# - scikit-learn — библиотека для машинного обучения:
#     - train_test_split — разделение данных на обучающую и тестовую выборки.
#     - classification_report, accuracy_score — оценка качества модели (точность, полнота, F1).
#     - roc_auc_score, confusion_matrix — ROC-AUC метрика и матрица ошибок.
# - catboost — библиотека градиентного бустинга
#     - CatBoostClassifier — классификатор с автоматической обработкой категориальных признаков.
# - time — замер времени обучения модели.
# - matplotlib.pyplot — построение графиков зависимости времени от объема данных и числа потоков.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from catboost import CatBoostClassifier
import time
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, confusion_matrix

# %% [markdown]
# ## Загрузка исходных данных
#
# Формируется список CSV-файлов, содержащих данные исследования.
#
# Файлы объединяются в единый DataFrame `df`. - для работы как с единой таблицей

# %%
files = [
    "../archive/AHS_Woman_08_Rajasthan/AHS_Woman_08_Rajasthan.csv",
    "../archive/AHS_Woman_10_Bihar/AHS_Woman_10_Bihar_Part_1.csv",
    "../archive/AHS_Woman_10_Bihar/AHS_Woman_10_Bihar_Part_2.csv",
    "../archive/AHS_Woman_18_Assam/AHS_Woman_18_Assam.csv",
    "../archive/AHS_Woman_20_Jharkhand/AHS_Woman_20_Jharkhand.csv",
    "../archive/AHS_Woman_21_Odisha/AHS_Woman_21_Odisha.csv",
    "../archive/AHS_Woman_22_Chhattisgarh/AHS_Woman_22_Chhattisgarh.csv",
    "../archive/AHS_Woman_23_Madhya_Pradesh/AHS_Woman_23_Madhya_Pradesh_Part_1.csv",
    "../archive/AHS_Woman_23_Madhya_Pradesh/AHS_Woman_23_Madhya_Pradesh_Part_2.csv"
]

dfs = []

for f in files:
    print("Чтение:", f)
    temp = pd.read_csv(f, sep="|", low_memory=False)
    dfs.append(temp)

df = pd.concat(dfs, ignore_index=True)

print("Датасет собран")
print("Размер датасета:", df.shape)
# Out:
# Чтение: ../archive/AHS_Woman_08_Rajasthan/AHS_Woman_08_Rajasthan.csv
# Чтение: ../archive/AHS_Woman_10_Bihar/AHS_Woman_10_Bihar_Part_1.csv
# Чтение: ../archive/AHS_Woman_10_Bihar/AHS_Woman_10_Bihar_Part_2.csv
# Чтение: ../archive/AHS_Woman_18_Assam/AHS_Woman_18_Assam.csv
# Чтение: ../archive/AHS_Woman_20_Jharkhand/AHS_Woman_20_Jharkhand.csv
# Чтение: ../archive/AHS_Woman_21_Odisha/AHS_Woman_21_Odisha.csv
# Чтение: ../archive/AHS_Woman_22_Chhattisgarh/AHS_Woman_22_Chhattisgarh.csv
# Чтение: ../archive/AHS_Woman_23_Madhya_Pradesh/AHS_Woman_23_Madhya_Pradesh_Part_1.csv
# Чтение: ../archive/AHS_Woman_23_Madhya_Pradesh/AHS_Woman_23_Madhya_Pradesh_Part_2.csv
# Датасет собран
# Размер датасета: (8299069, 202)

# %% [markdown]
# ## Первичный анализ структуры данных
#
# Разведочная проверка (EDA):
#
# 1. Вывод списка всех колонок датасета.
# 2. Просмотр первых строк таблицы.
# 3. Анализ распределения целевой переменной `outcome_pregnancy`.
# 4. Проверка количества пропущенных значений в каждом столбце.

# %%
print("\nСписок колонок:")
print(df.columns)

print("\nПервые строки данных:")
print(df.head())

print("\nРаспределение целевой переменной - до очистки:")
print(df["outcome_pregnancy"].value_counts())

print("\nКоличество пропущенных значений по колонкам:")
print(df.isnull().sum())

print("\nТипы данных колонок:")
print(df.dtypes)
# Out:
# Список колонок:
# Index(['w_id', 'hl_id', 'client_w_id', 'state', 'district', 'rural',
#        'stratum_code', 'psu_id', 'house_no', 'house_hold_no',
#        ...
#        'anym', 'respondentname', 'rtelephoneno', 'isnewrecord',
#        'recordupdatedcount', 'recordstatus', 'schedule_id', 'year', 'id',
#        'v204'],
#       dtype='object', length=202)
#
# Первые строки данных:
#    w_id hl_id  client_w_id  state  district  rural  stratum_code     psu_id  \
# 0   NaN   NaN          NaN      8        21      1             1  101431218
# 1   NaN   NaN          NaN      8        21      1             1  101431169
# 2   NaN   NaN          NaN      8        21      1             1  101431095
# 3   NaN   NaN          NaN      8        21      1             1  101431064
# 4   NaN   NaN          NaN      8        21      1             1  101431121
#
#    house_no  house_hold_no  ...  anym  respondentname  rtelephoneno  \
# 0        24              2  ...   NaN             NaN           NaN
# 1        25              1  ...   NaN             NaN           NaN
# 2        26              1  ...   NaN             NaN           NaN
# 3        27              1  ...   NaN             NaN           NaN
# 4        31              1  ...   NaN             NaN           NaN
#
#    isnewrecord recordupdatedcount  recordstatus schedule_id  year         id  \
# 0          1.0                2.0           2.0         2.0   3.0  1725828.0
# 1          NaN                1.0           2.0         2.0   3.0  1725829.0
# 2          NaN                2.0           2.0         2.0   3.0  1725830.0
# 3          NaN                1.0           2.0         2.0   3.0  1725831.0
# 4          NaN                1.0           2.0         2.0   3.0  1725832.0
#
#   v204
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 202 columns]
#
# Распределение целевой переменной - до очистки:
# outcome_pregnancy
# 2.0     4471773
# 2       1646256
# 1.0      960212
# 1        362812
# 0.0        2111
#            1855
# 0           581
# 23.0          1
# 27            1
# Name: count, dtype: int64
#
# Количество пропущенных значений по колонкам:
# w_id            5222832
# hl_id           5211506
# client_w_id     5222833
# state                 0
# district              0
#                  ...
# recordstatus    3076475
# schedule_id          34
# year                 34
# id                   36
# v204            8299067
# Length: 202, dtype: int64
#
# Типы данных колонок:
# w_id            float64
# hl_id            object
# client_w_id     float64
# state             int64
# district          int64
#                  ...
# recordstatus    float64
# schedule_id     float64
# year            float64
# id              float64
# v204            float64
# Length: 202, dtype: object

# %% [markdown]
# ## Очистка и подготовка целевой переменной
#
# Целевая переменная `outcome_pregnancy` приводится к числовому типу данных.
#
# Далее выполняется очистка выборки:
# - удаляются строки с отсутствующим значением целевой переменной;
# - оставляются только наблюдения с корректными значениями классов (1 и 2).

# %%
df["outcome_pregnancy"] = pd.to_numeric(df["outcome_pregnancy"], errors="coerce")

df = df.dropna(subset=["outcome_pregnancy"])

df = df[df["outcome_pregnancy"].isin([1, 2])]

print("Очищенная целевая переменная:")
print(df["outcome_pregnancy"].value_counts())
# Out:
# Очищенная целевая переменная:
# outcome_pregnancy
# 2.0    6118029
# 1.0    1323024
# Name: count, dtype: int64

# %% [markdown]
# ##### Удаление признаков с большим количеством пропусков
#
# Для каждого признака рассчитывается доля пропущенных значений.
#
# Если доля пропусков > 90%, признак считается нерелевантным и удаляется из датасета.

# %%
missing_ratio = df.isnull().mean()

cols_to_drop = missing_ratio[missing_ratio > 0.9].index

print("Колонки для удаления:", len(cols_to_drop))

df = df.drop(columns=cols_to_drop)

print("Размер датасета после удаления столбцов:", df.shape)
# Out:
# Колонки для удаления: 33
# Размер датасета после удаления столбцов: (7441053, 169)

# %% [markdown]
# #### Удаление служебных идентификаторов
#
# Из датасета удаляются столбцы, содержащие уникальные идентификаторы записей:
#
# - `w_id`
# - `hl_id`
# - `client_w_id`
# - `id`
# - `psu_id`

# %%
id_cols = [
    "w_id",
    "hl_id",
    "client_w_id",
    "id",
    "psu_id"
]

df = df.drop(columns=[c for c in id_cols if c in df.columns])

print("Размер датасета после удаления колонок ID:", df.shape)
# Out:
# Размер датасета после удаления колонок ID: (7441053, 164)

# %% [markdown]
# ## Снижение размера датасета
#
# Для ускорения обучения модели из исходного набора данных выбирается подвыборка размером 50 000 наблюдений.
#
# Используется стратифицированная выборка, чтобы сохранить исходное распределение классов целевой переменной.

# %%
# Снижение размера датасета с учетом штата человека

print("Исходный размер датасета:", len(df))
print("Исходное распределение по штатам:")
print(df['state'].value_counts())

df['_stratify'] = df['state'].astype(str) + '_' + df['outcome_pregnancy'].astype(str)

df, _ = train_test_split(
    df,
    train_size=50000,
    stratify=df['_stratify'],
    random_state=5
)

df = df.drop(columns=['_stratify'])

print("\nРазмер после выборки:", len(df))
print("\nРаспределение по штатам после выборки:")
state_dist = df['state'].value_counts()
print(state_dist)
print(f"\nКоличество штатов в выборке: {len(state_dist)}")
# Out:
# Исходный размер датасета: 7441053
# Исходное распределение по штатам:
# state
# 10    1527097
# 23    1234197
# 20    1075369
# 21    1063029
# 18     933699
# 8      901580
# 22     706082
# Name: count, dtype: int64
#
# Размер после выборки: 50000
#
# Распределение по штатам после выборки:
# state
# 10    10261
# 23     8293
# 20     7226
# 21     7143
# 18     6274
# 8      6058
# 22     4745
# Name: count, dtype: int64
#
# Количество штатов в выборке: 7

# %% [markdown]
# ## Определение числовых и категориальных признаков
#
# На данном этапе признаки разделяются на две группы:
#
# - Числовые признаки
# - Категориальные признаки
#
# Целевая переменная `outcome_pregnancy` исключается из списка признаков.
#
# Необходимо для дальнейшей корректной обработки пропусков и кодирования категориальных данных.

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
cat_cols = df.select_dtypes(include=["object"]).columns

if "outcome_pregnancy" in num_cols:
    num_cols = num_cols.drop("outcome_pregnancy")

print("Числовые признаки:", len(num_cols))
print("Категориальные признаки:", len(cat_cols))
# Out:
# Числовые признаки: 23
# Категориальные признаки: 140

# %% [markdown]
# ## Заполнение пропущенных значений
#
# Пропуски обрабатываются отдельно для разных типов данных:
#
# - для числовых признаков пропущенные значения заменяются медианой;
# - для категориальных признаков используется категория `"Unknown"`.
#
# После выполнения операции проверяется, что в датасете больше нет пропущенных значений.

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].median(numeric_only=True))

df[cat_cols] = df[cat_cols].fillna("Unknown")

print("Пропущенные значения после чистки:", df.isnull().sum().sum())
# Out:
# Пропущенные значения после чистки: 0

# %%
X = df.drop(columns=["outcome_pregnancy"])
y = df["outcome_pregnancy"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (50000, 163)
# y shape: (50000,)

# %% [markdown]
# ## Разделение данных на обучающую и тестовую выборки
#
# Данные разделяются в пропорции 80/20:
#
# - обучающая выборка — используется для обучения модели;
# - тестовая выборка — используется для оценки качества модели.
#
# Разделение выполняется стратифицированно по целевой переменной, чтобы сохранить баланс классов.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=5
)

print("обучающая выборка:", len(X_train))
print("тестовая выборка:", len(X_test))
# Out:
# обучающая выборка: 40000
# тестовая выборка: 10000

# %% [markdown]
# ### Настройки алгоритма CatBoost
#
# Для построения модели используется алгоритм градиентного бустинга CatBoost.
#
# Параметры модели:
# - `iterations = 300` — количество итераций (деревьев)
# - `depth = 8` — глубина деревьев
# - `learning_rate = 0.05` — скорость обучения
#
# Параметры подобраны эмпирически и обеспечивают баланс между качеством модели и временем обучения.

# %%
# Категориальные признаки
cat_cols = X_train.select_dtypes(include=['object']).columns.tolist()

# все категориальные колонки - к строкам
X_train_clean = X_train.copy()
X_test_clean = X_test.copy()
X_train_clean[cat_cols] = X_train_clean[cat_cols].astype(str)
X_test_clean[cat_cols] = X_test_clean[cat_cols].astype(str)

# Модель
model = CatBoostClassifier(
    iterations=300,
    depth=8,
    learning_rate=0.05,
    loss_function='Logloss',
    cat_features=cat_cols,
    verbose=100,
    random_seed=42,
    thread_count=-1,       
    early_stopping_rounds=50
)

# обучение на очищенных данных
start = time.time()
model.fit(X_train_clean, y_train) 
train_time = time.time() - start
print(f"Время обучения: {train_time:.2f} сек")

# предсказание на очищенных данных
y_pred = model.predict(X_test_clean)
# Out:
# 0:	learn: 0.5992676	total: 394ms	remaining: 1m 57s
# 100:	learn: 0.0736686	total: 22.3s	remaining: 44s
# 200:	learn: 0.0667386	total: 43s	remaining: 21.2s
# 299:	learn: 0.0626097	total: 1m 5s	remaining: 0us
# Время обучения: 67.13 сек

# %% [markdown]
# ### Оценка качества модели
#
# После обучения модель проверяется на тестовой выборке.
#
# Используются следующие метрики:
# - Accuracy — доля правильных ответов
# - ROC-AUC — качество ранжирования
# - Classification Report — точность, полнота и F1-мера по классам
#
# Также строится матрица ошибок (confusion matrix).

# %%
# Предсказание на тестовой выборке
y_pred = model.predict(X_test_clean)
y_proba = model.predict_proba(X_test_clean)[:, 1]

# Метрики
print("Оценка модели на тестовой выборке")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"ROC-AUC: {roc_auc_score(y_test, y_proba):.4f}")
print("\Отчет о классификации:")
print(classification_report(y_test, y_pred))
print("\Матрица смешения:")
print(confusion_matrix(y_test, y_pred))

# Важность признаков - 10 штук
import pandas as pd
feature_importance = model.get_feature_importance()
feature_names = X_train_clean.columns
importance_df = pd.DataFrame({'feature': feature_names, 'importance': feature_importance})
importance_df = importance_df.sort_values('importance', ascending=False).head(10)
print("\nТоп-10 важнейших признаков:")
print(importance_df)
# Out:
# Оценка модели на тестовой выборке
# Accuracy: 0.9747
# ROC-AUC: 0.9881
# \Отчет о классификации:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.87      0.92      1778
#          2.0       0.97      1.00      0.98      8222
#
#     accuracy                           0.97     10000
#    macro avg       0.98      0.93      0.95     10000
# weighted avg       0.97      0.97      0.97     10000
#
# \Матрица смешения:
# [[1550  228]
#  [  25 8197]]
#
# Топ-10 важнейших признаков:
#                         feature  importance
# 22                 last_preg_no   32.165383
# 136  is_husband_living_with_you   18.378558
# 60         anm_in_last_3_months    8.615354
# 84             year_of_marriage    3.202201
# 45    is_currently_menstruating    2.540060
# 79                year_of_birth    2.465257
# 131              ever_conceived    2.163894
# 159          recordupdatedcount    2.147638
# 157                        cdoi    2.067940
# 12                          age    1.782398

# %%
# Сравнение распределения реальных и предсказанных классов
print("\nСравнение распределения исходов")
print("Реальное распределение в тестовой выборке:")
print(y_test.value_counts(normalize=True))
print("\nПредсказанное распределение:")
print(pd.Series(y_pred).value_counts(normalize=True))
# Out:
# Сравнение распределения исходов
# Реальное распределение в тестовой выборке:
# outcome_pregnancy
# 2.0    0.8222
# 1.0    0.1778
# Name: proportion, dtype: float64
#
# Предсказанное распределение:
# 2.0    0.8425
# 1.0    0.1575
# Name: proportion, dtype: float64

# %% [markdown]
# ### Анализ зависимости времени обучения от объема данных
#
# Проводится эксперимент, в котором модель обучается на выборках различного размера.
#
# Цель — определить, как масштаб данных влияет на время построения модели.

# %%
sample_sizes = [10000, 20000, 30000, 40000]
times_vs_size = []

for size in sample_sizes:
    # Случайная подвыборка строк без разделения на обучающую и тестовую
    X_sample = X_train_clean.sample(n=size, random_state=5)
    y_sample = y_train.loc[X_sample.index]  
    
    model_tmp = CatBoostClassifier(
        iterations=300, depth=8, learning_rate=0.05,
        cat_features=cat_cols, verbose=False, random_seed=5, thread_count=-1
    )
    start = time.time()
    model_tmp.fit(X_sample, y_sample)
    elapsed = time.time() - start
    times_vs_size.append(elapsed)
    print(f"Размер {size}: {elapsed:.2f} сек")

# таблицы
print("\nРазмер\tВремя (сек)")
for s, t in zip(sample_sizes, times_vs_size):
    print(f"{s}\t{t:.2f}")
# Out:
# Размер 10000: 27.19 сек
# Размер 20000: 41.52 сек
# Размер 30000: 53.80 сек
# Размер 40000: 68.79 сек
#
# Размер	Время (сек)
# 10000	27.19
# 20000	41.52
# 30000	53.80
# 40000	68.79

# %% [markdown]
# ### Анализ параллельного выполнения
#
# Алгоритм CatBoost поддерживает многопоточное выполнение.
#
# В данном эксперименте варьируется параметр `thread_count`, который задает количество используемых потоков.
#
# Цель — оценить влияние параллелизма на время обучения модели.

# %%
thread_counts = [1, 2, 4, 8]
times_vs_threads = []

for thr in thread_counts:
    model_tmp = CatBoostClassifier(
        iterations=300, depth=8, learning_rate=0.05,
        cat_features=cat_cols, verbose=False, random_seed=42, thread_count=thr
    )
    start = time.time()
    model_tmp.fit(X_train_clean, y_train)
    elapsed = time.time() - start
    times_vs_threads.append(elapsed)
    print(f"Количество потоков={thr}: {elapsed:.2f} сек")
# Out:
# Количество потоков=1: 436.03 сек
# Количество потоков=2: 223.55 сек
# Количество потоков=4: 117.00 сек
# Количество потоков=8: 69.11 сек

# %% [markdown]
# ## Построение графиков

# %%
# График времени от объёма данных
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(sample_sizes, times_vs_size, marker='o')
plt.xlabel('Размер выборки')
plt.ylabel('Время обучения (сек)')
plt.title('Зависимость времени от объёма данных')
plt.grid(True)

# График времени от числа потоков
plt.subplot(1,2,2)
plt.plot(thread_counts, times_vs_threads, marker='s')
plt.xlabel('Количество потоков')
plt.ylabel('Время обучения (сек)')
plt.title('Зависимость времени от числа потоков')
plt.grid(True)
plt.tight_layout()
plt.show()

# График ускорения
speedup = [times_vs_threads[0]/t for t in times_vs_threads]
plt.plot(thread_counts, speedup, marker='^', label='Реальное ускорение')
plt.plot(thread_counts, thread_counts, '--', label='Идеальное ускорение')
plt.xlabel('Потоки')
plt.ylabel('Ускорение')
plt.legend()
plt.grid(True)
plt.show()
